# %%
map = [9101109,17061709,13181320,11051306,13151316,14141514,12081209,11181119,7030902,12111410,7070908,5040703,12131315,9061105,11211123,16111711,11171118,11151117,15071706,11071207,7110912,5090512,5120713,9141115,13151414,7070709,18041905,15051706,5060508,11081109,11011103,11281130,11111211,7070906,17041804,3130514,13041505,9081107,7130914,9041103,14101510,17111912,12091211,17061905,13261328,13251326,13161318,9061107,15071510,5140815,12071308,15101711,5040705,17091711,3050504,11051107,12091309,19051908,11231125,3080310,11131213,12111213,9021101,12131412,5080509,11191121,13201322,13281330,11031105,13081507,11251128,9121113,11081208,11151213,19081910,15031704,7050904,9080910,10161117,11091208,11091209,13061507,13081309,14121611,3100313,9081109,7050906,13091510,5060707,17131912,13021503,19101912,5120711,8151016,7090711,3050506,11031304,11011302,5060705,3060308,3050306,3130512,13221325,15141713,9101111,7110910]
x = [int(a / 10000) for a in map];
y = [int(a % 10000) for a in map];
x
y
# Out:
# [1109,
#  1709,
#  1320,
#  1306,
#  1316,
#  1514,
#  1209,
#  1119,
#  902,
#  1410,
#  908,
#  703,
#  1315,
#  1105,
#  1123,
#  1711,
#  1118,
#  1117,
#  1706,
#  1207,
#  912,
#  512,
#  713,
#  1115,
#  1414,
#  709,
#  1905,
#  1706,
#  508,
#  1109,
#  1103,
#  1130,
#  1211,
#  906,
#  1804,
#  514,
#  1505,
#  1107,
#  914,
#  1103,
#  1510,
#  1912,
#  1211,
#  1905,
#  1328,
#  1326,
#  1318,
#  1107,
#  1510,
#  815,
#  1308,
#  1711,
#  705,
#  1711,
#  504,
#  1107,
#  1309,
#  1908,
#  1125,
#  310,
#  1213,
#  1213,
#  1101,
#  1412,
#  509,
#  1121,
#  1322,
#  1330,
#  1105,
#  1507,
#  1128,
#  1113,
#  1208,
#  1213,
#  1910,
#  1704,
#  904,
#  910,
#  1117,
#  1208,
#  1209,
#  1507,
#  1309,
#  1611,
#  313,
#  1109,
#  906,
#  1510,
#  707,
#  1912,
#  1503,
#  1912,
#  711,
#  1016,
#  711,
#  506,
#  1304,
#  1302,
#  705,
#  308,
#  306,
#  512,
#  1325,
#  1713,
#  1111,
#  910]
